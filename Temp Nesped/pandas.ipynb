# %%
import pandas as pd

# %%
df = pd.read_csv("wine.csv")
df
# Out:
#      Wine  Alcohol  Malic.acid   Ash   Acl   Mg  Phenols  Flavanoids  \
# 0       1    14.23        1.71  2.43  15.6  127     2.80        3.06
# 1       1    13.20        1.78  2.14  11.2  100     2.65        2.76
# 2       1    13.16        2.36  2.67  18.6  101     2.80        3.24
# 3       1    14.37        1.95  2.50  16.8  113     3.85        3.49
# 4       1    13.24        2.59  2.87  21.0  118     2.80        2.69
# ..    ...      ...         ...   ...   ...  ...      ...         ...
# 173     3    13.71        5.65  2.45  20.5   95     1.68        0.61
# 174     3    13.40        3.91  2.48  23.0  102     1.80        0.75
# 175     3    13.27        4.28  2.26  20.0  120     1.59        0.69
# 176     3    13.17        2.59  2.37  20.0  120     1.65        0.68
# 177     3    14.13        4.10  2.74  24.5   96     2.05        0.76
#
#      Nonflavanoid.phenols  Proanth  Color.int   Hue    OD  Proline
# 0                    0.28     2.29       5.64  1.04  3.92     1065
# ...

# %%
df.groupby(["Wine", "Phenols"]).first().head(50)
# Out:
#               Alcohol  Malic.acid   Ash   Acl   Mg  Flavanoids  \
# Wine Phenols
# 1    2.20       14.12        1.48  2.32  16.8   95        2.43
#      2.35       13.51        1.80  2.65  19.0  110        2.53
#      2.40       13.30        1.72  2.14  17.0   94        2.19
#      2.41       12.93        3.80  2.65  18.6  102        2.41
#      2.42       13.68        1.83  2.36  17.2  104        2.69
#      2.45       13.05        1.65  2.55  18.0   98        2.43
#      2.48       12.85        1.60  2.52  17.8   95        2.37
#      2.50       14.39        1.87  2.45  14.6   96        2.52
#      2.53       13.50        1.81  2.61  20.0   96        2.61
#      2.60       14.06        2.15  2.61  17.6  121        2.51
#      2.61       13.71        1.86  2.36  16.6  101        2.88
#      2.63       13.05        2.05  3.22  25.0  124        2.68
#      2.64       13.24        3.98  2.29  17.5  103        2.63
#      2.65       13.20        1.78  2.14  11.2  100        2.76
# ...

# %%
df['Alcohol']*2
# Out:
# 0      28.46
# 1      26.40
# 2      26.32
# 3      28.74
# 4      26.48
#        ...
# 173    27.42
# 174    26.80
# 175    26.54
# 176    26.34
# 177    28.26
# Name: Alcohol, Length: 178, dtype: float64
